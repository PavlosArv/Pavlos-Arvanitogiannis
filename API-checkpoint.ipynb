# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# C:\Users\parva\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10161
# 1   1027     Ethereum    ETH      ethereum              6727
# 2    825       Tether   USDT        tether             51257
# 3   1839          BNB    BNB           bnb              1256
# 4   3408     USD Coin   USDC      usd-coin             11786
# 5     52          XRP    XRP           xrp               931
# 6   2010      Cardano    ADA       cardano               765
# 7     74     Dogecoin   DOGE      dogecoin               683
# 8   3890      Polygon  MATIC       polygon               654
# 9   5426       Solana    SOL        solana               455
# 10  6636     Polkadot    DOT  polkadot-new               497
# 11     2     Litecoin    LTC      litecoin               903
# 12  4687  Binance USD   BUSD   binance-usd              6603
# 13  5994    Shiba Inu   SHIB     shiba-inu               503
# 14  5805    Avalanche   AVAX     avalanche               402
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2020-04-10T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2019-09-20T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 9   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 14  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.934612e+07  1.934612e+07            False       NaN         1
# 1         1.202176e+08  1.202176e+08            False       NaN         2
# 2         8.076531e+10  8.309174e+10            False       NaN         3
# 3         1.558661e+08  1.558661e+08            False       NaN         4
# 4         3.180231e+10  3.180231e+10            False       NaN         5
# 5         5.175081e+10  9.998900e+10            False       NaN         6
# 6         3.477415e+10  3.567775e+10            False       NaN         7
# 7         1.389370e+11  1.389370e+11            False       NaN         8
# 8         9.219469e+09  1.000000e+10            False       NaN         9
# 9         3.917707e+08  5.393127e+08            False       NaN        10
# 10        1.176098e+09  1.302577e+09            False       NaN        11
# 11        7.270374e+07  8.400000e+07            False       NaN        12
# 12        6.715537e+09  6.715537e+09            False       NaN        13
# 13        5.895369e+14  5.896051e+14            False       NaN        14
# 14        3.261928e+08  4.222555e+08            False       NaN        15
#
#    self_reported_circulating_supply self_reported_market_cap tvl_ratio  \
# 0                              None                     None      None
# 1                              None                     None      None
# 2                              None                     None      None
# 3                              None                     None      None
# 4                              None                     None      None
# 5                              None                     None      None
# 6                              None                     None      None
# 7                              None                     None      None
# 8                              None                     None      None
# 9                              None                     None      None
# 10                             None                     None      None
# 11                             None                     None      None
# 12                             None                     None      None
# 13                             None                     None      None
# 14                             None                     None      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-04-14T17:38:00.000Z     30236.490720          2.235445e+10
# 1   2023-04-14T17:38:00.000Z      2073.905774          1.564248e+10
# 2   2023-04-14T17:38:00.000Z         1.000503          4.139497e+10
# 3   2023-04-14T17:38:00.000Z       326.930069          9.193914e+08
# 4   2023-04-14T17:38:00.000Z         0.999600          6.111025e+09
# 5   2023-04-14T17:38:00.000Z         0.518693          1.568177e+09
# 6   2023-04-14T17:38:00.000Z         0.431377          7.807434e+08
# 7   2023-04-14T17:38:00.000Z         0.088630          9.874831e+08
# 8   2023-04-14T17:38:00.000Z         1.150639          5.836754e+08
# 9   2023-04-14T17:38:00.000Z        24.142940          8.154354e+08
# 10  2023-04-14T17:38:00.000Z         6.643029          2.971149e+08
# 11  2023-04-14T17:38:00.000Z        94.817712          8.178922e+08
# 12  2023-04-14T17:38:00.000Z         1.000369          4.150944e+09
# 13  2023-04-14T17:38:00.000Z         0.000011          2.885907e+08
# 14  2023-04-14T17:38:00.000Z        18.693959          2.350606e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       26.6576                     0.344193
# 1                       20.6871                     1.031570
# 2                       30.5424                     0.019565
# 3                       32.9711                     0.770163
# 4                       33.9906                     0.020021
# 5                       62.4619                     0.784870
# 6                       65.9592                     0.671157
# 7                       13.9332                     2.615071
# 8                       99.6700                     0.823160
# 9                      -13.2162                     1.151335
# 10                      51.3634                     1.269645
# 11                      61.5631                     0.755742
# 12                       5.1070                     0.004525
# 13                      66.5393                     0.967489
# 14                     -13.9698                     0.849498
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -0.442402                     8.218917
# 1                       3.158096                    11.577016
# 2                      -0.038723                    -0.003691
# 3                       0.752487                     5.031548
# 4                      -0.021590                    -0.032047
# 5                       1.622062                     1.642192
# 6                       3.816343                    12.367605
# 7                       0.961567                     7.385864
# 8                       1.354253                     3.646069
# 9                      -2.026373                    17.587764
# 10                      0.650399                     7.286993
# 11                      0.584326                     4.783894
# 12                     -0.031253                     0.057372
# 13                      0.192056                     2.165136
# 14                     -1.348222                     6.043079
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      24.085500                     40.500681
# 1                      27.114842                     40.522464
# 2                      -0.134208                     -0.048470
# 3                       7.572327                     14.658772
# 4                       0.029786                     -0.020697
# 5                      43.694240                     42.057695
# 6                      33.986168                     23.727911
# 7                      28.821969                     10.118097
# 8                       4.700261                     -0.093392
# 9                      26.887971                     20.854252
# 10                     12.947649                     11.683847
# 11                     24.259923                      5.666235
# 12                      0.038375                      0.092397
# 13                      7.762071                     -7.725993
# 14                     19.388320                      9.461295
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      44.883737          5.849589e+11
# 1                      35.226270          2.493199e+11
# 2                       0.032373          8.080595e+10
# 3                       7.222171          5.095730e+10
# 4                      -0.042221          3.178959e+10
# 5                      31.730232          2.684278e+10
# 6                      22.504114          1.500077e+10
# 7                       1.562580          1.231402e+10
# 8                      16.017626          1.060828e+10
# 9                       4.344780          9.458497e+09
# 10                      8.754320          7.812852e+09
# 11                      7.532908          6.893602e+09
# 12                      0.001215          6.718014e+09
# 13                      7.875851          6.584798e+09
# 14                      9.933214          6.097835e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          46.3186                        6.349663e+11
# 1                          19.7391                        2.493199e+11
# 2                           6.3976                        8.313355e+10
# 3                           4.0348                        5.095730e+10
# 4                           2.5171                        3.178959e+10
# 5                           2.1254                        5.186930e+10
# 6                           1.1876                        1.941196e+10
# 7                           0.9750                        1.231402e+10
# 8                           0.8400                        1.150639e+10
# 9                           0.7488                        1.302059e+10
# 10                          0.6186                        8.653054e+09
# 11                          0.5458                        7.964688e+09
# 12                          0.5319                        6.718014e+09
# 13                          0.5214                        6.585560e+09
# 14                          0.4828                        1.345965e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 1           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 2           None  2023-04-14T17:38:00.000Z       1027.0      Ethereum
# 3           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 4           None  2023-04-14T17:38:00.000Z       1027.0      Ethereum
# 5           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 6           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 7           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 8           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 9           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 10          None  2023-04-14T17:38:00.000Z          NaN           NaN
# 11          None  2023-04-14T17:38:00.000Z          NaN           NaN
# 12          None  2023-04-14T17:38:00.000Z       1839.0           BNB
# 13          None  2023-04-14T17:38:00.000Z       1027.0      Ethereum
# 14          None  2023-04-14T17:38:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             BNB           bnb                                    BUSD-BD1
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-04-14 17:40:57.273952
# 1  2023-04-14 17:40:57.273952
# 2  2023-04-14 17:40:57.273952
# 3  2023-04-14 17:40:57.273952
# 4  2023-04-14 17:40:57.273952
# 5  2023-04-14 17:40:57.273952
# 6  2023-04-14 17:40:57.273952
# 7  2023-04-14 17:40:57.273952
# 8  2023-04-14 17:40:57.273952
# 9  2023-04-14 17:40:57.273952
# 10 2023-04-14 17:40:57.273952
# 11 2023-04-14 17:40:57.273952
# 12 2023-04-14 17:40:57.273952
# 13 2023-04-14 17:40:57.273952
# 14 2023-04-14 17:40:57.273952

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11280\314683833.py in <module>
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10161
# 1   1027     Ethereum    ETH      ethereum              6727
# 2    825       Tether   USDT        tether             51257
# 3   1839          BNB    BNB           bnb              1256
# 4   3408     USD Coin   USDC      usd-coin             11786
# 5     52          XRP    XRP           xrp               931
# 6   2010      Cardano    ADA       cardano               765
# 7     74     Dogecoin   DOGE      dogecoin               683
# 8   3890      Polygon  MATIC       polygon               654
# 9   5426       Solana    SOL        solana               455
# 10  6636     Polkadot    DOT  polkadot-new               497
# 11     2     Litecoin    LTC      litecoin               903
# 12  4687  Binance USD   BUSD   binance-usd              6603
# 13  5994    Shiba Inu   SHIB     shiba-inu               503
# 14  5805    Avalanche   AVAX     avalanche               402
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2020-04-10T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2019-09-20T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 9   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 14  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.934612e+07  1.934612e+07            False       NaN         1
# 1         1.202176e+08  1.202176e+08            False       NaN         2
# 2         8.076531e+10  8.309174e+10            False       NaN         3
# 3         1.558661e+08  1.558661e+08            False       NaN         4
# 4         3.180231e+10  3.180231e+10            False       NaN         5
# 5         5.175081e+10  9.998900e+10            False       NaN         6
# 6         3.477415e+10  3.567775e+10            False       NaN         7
# 7         1.389370e+11  1.389370e+11            False       NaN         8
# 8         9.219469e+09  1.000000e+10            False       NaN         9
# 9         3.917707e+08  5.393127e+08            False       NaN        10
# 10        1.176098e+09  1.302577e+09            False       NaN        11
# 11        7.270374e+07  8.400000e+07            False       NaN        12
# 12        6.715537e+09  6.715537e+09            False       NaN        13
# 13        5.895369e+14  5.896051e+14            False       NaN        14
# 14        3.261928e+08  4.222555e+08            False       NaN        15
#
#    self_reported_circulating_supply self_reported_market_cap tvl_ratio  \
# 0                              None                     None      None
# 1                              None                     None      None
# 2                              None                     None      None
# 3                              None                     None      None
# 4                              None                     None      None
# 5                              None                     None      None
# 6                              None                     None      None
# 7                              None                     None      None
# 8                              None                     None      None
# 9                              None                     None      None
# 10                             None                     None      None
# 11                             None                     None      None
# 12                             None                     None      None
# 13                             None                     None      None
# 14                             None                     None      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-04-14T17:38:00.000Z     30236.490720          2.235445e+10
# 1   2023-04-14T17:38:00.000Z      2073.905774          1.564248e+10
# 2   2023-04-14T17:38:00.000Z         1.000503          4.139497e+10
# 3   2023-04-14T17:38:00.000Z       326.930069          9.193914e+08
# 4   2023-04-14T17:38:00.000Z         0.999600          6.111025e+09
# 5   2023-04-14T17:38:00.000Z         0.518693          1.568177e+09
# 6   2023-04-14T17:38:00.000Z         0.431377          7.807434e+08
# 7   2023-04-14T17:38:00.000Z         0.088630          9.874831e+08
# 8   2023-04-14T17:38:00.000Z         1.150639          5.836754e+08
# 9   2023-04-14T17:38:00.000Z        24.142940          8.154354e+08
# 10  2023-04-14T17:38:00.000Z         6.643029          2.971149e+08
# 11  2023-04-14T17:38:00.000Z        94.817712          8.178922e+08
# 12  2023-04-14T17:38:00.000Z         1.000369          4.150944e+09
# 13  2023-04-14T17:38:00.000Z         0.000011          2.885907e+08
# 14  2023-04-14T17:38:00.000Z        18.693959          2.350606e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       26.6576                     0.344193
# 1                       20.6871                     1.031570
# 2                       30.5424                     0.019565
# 3                       32.9711                     0.770163
# 4                       33.9906                     0.020021
# 5                       62.4619                     0.784870
# 6                       65.9592                     0.671157
# 7                       13.9332                     2.615071
# 8                       99.6700                     0.823160
# 9                      -13.2162                     1.151335
# 10                      51.3634                     1.269645
# 11                      61.5631                     0.755742
# 12                       5.1070                     0.004525
# 13                      66.5393                     0.967489
# 14                     -13.9698                     0.849498
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -0.442402                     8.218917
# 1                       3.158096                    11.577016
# 2                      -0.038723                    -0.003691
# 3                       0.752487                     5.031548
# 4                      -0.021590                    -0.032047
# 5                       1.622062                     1.642192
# 6                       3.816343                    12.367605
# 7                       0.961567                     7.385864
# 8                       1.354253                     3.646069
# 9                      -2.026373                    17.587764
# 10                      0.650399                     7.286993
# 11                      0.584326                     4.783894
# 12                     -0.031253                     0.057372
# 13                      0.192056                     2.165136
# 14                     -1.348222                     6.043079
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      24.085500                     40.500681
# 1                      27.114842                     40.522464
# 2                      -0.134208                     -0.048470
# 3                       7.572327                     14.658772
# 4                       0.029786                     -0.020697
# 5                      43.694240                     42.057695
# 6                      33.986168                     23.727911
# 7                      28.821969                     10.118097
# 8                       4.700261                     -0.093392
# 9                      26.887971                     20.854252
# 10                     12.947649                     11.683847
# 11                     24.259923                      5.666235
# 12                      0.038375                      0.092397
# 13                      7.762071                     -7.725993
# 14                     19.388320                      9.461295
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      44.883737          5.849589e+11
# 1                      35.226270          2.493199e+11
# 2                       0.032373          8.080595e+10
# 3                       7.222171          5.095730e+10
# 4                      -0.042221          3.178959e+10
# 5                      31.730232          2.684278e+10
# 6                      22.504114          1.500077e+10
# 7                       1.562580          1.231402e+10
# 8                      16.017626          1.060828e+10
# 9                       4.344780          9.458497e+09
# 10                      8.754320          7.812852e+09
# 11                      7.532908          6.893602e+09
# 12                      0.001215          6.718014e+09
# 13                      7.875851          6.584798e+09
# 14                      9.933214          6.097835e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          46.3186                        6.349663e+11
# 1                          19.7391                        2.493199e+11
# 2                           6.3976                        8.313355e+10
# 3                           4.0348                        5.095730e+10
# 4                           2.5171                        3.178959e+10
# 5                           2.1254                        5.186930e+10
# 6                           1.1876                        1.941196e+10
# 7                           0.9750                        1.231402e+10
# 8                           0.8400                        1.150639e+10
# 9                           0.7488                        1.302059e+10
# 10                          0.6186                        8.653054e+09
# 11                          0.5458                        7.964688e+09
# 12                          0.5319                        6.718014e+09
# 13                          0.5214                        6.585560e+09
# 14                          0.4828                        1.345965e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 1           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 2           None  2023-04-14T17:38:00.000Z       1027.0      Ethereum
# 3           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 4           None  2023-04-14T17:38:00.000Z       1027.0      Ethereum
# 5           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 6           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 7           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 8           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 9           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 10          None  2023-04-14T17:38:00.000Z          NaN           NaN
# 11          None  2023-04-14T17:38:00.000Z          NaN           NaN
# 12          None  2023-04-14T17:38:00.000Z       1839.0           BNB
# 13          None  2023-04-14T17:38:00.000Z       1027.0      Ethereum
# 14          None  2023-04-14T17:38:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             BNB           bnb                                    BUSD-BD1
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-04-14 17:40:57.273952
# 1  2023-04-14 17:40:57.273952
# 2  2023-04-14 17:40:57.273952
# 3  2023-04-14 17:40:57.273952
# 4  2023-04-14 17:40:57.273952
# 5  2023-04-14 17:40:57.273952
# 6  2023-04-14 17:40:57.273952
# 7  2023-04-14 17:40:57.273952
# 8  2023-04-14 17:40:57.273952
# 9  2023-04-14 17:40:57.273952
# 10 2023-04-14 17:40:57.273952
# 11 2023-04-14 17:40:57.273952
# 12 2023-04-14 17:40:57.273952
# 13 2023-04-14 17:40:57.273952
# 14 2023-04-14 17:40:57.273952

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10161
# 1   1027     Ethereum    ETH      ethereum              6727
# 2    825       Tether   USDT        tether             51257
# 3   1839          BNB    BNB           bnb              1256
# 4   3408     USD Coin   USDC      usd-coin             11786
# 5     52          XRP    XRP           xrp               931
# 6   2010      Cardano    ADA       cardano               765
# 7     74     Dogecoin   DOGE      dogecoin               683
# 8   3890      Polygon  MATIC       polygon               654
# 9   5426       Solana    SOL        solana               455
# 10  6636     Polkadot    DOT  polkadot-new               497
# 11     2     Litecoin    LTC      litecoin               903
# 12  4687  Binance USD   BUSD   binance-usd              6603
# 13  5994    Shiba Inu   SHIB     shiba-inu               503
# 14  5805    Avalanche   AVAX     avalanche               402
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2020-04-10T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2019-09-20T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 5   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 6   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 7   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  10000000000.00000
# 9   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]     84000000.00000
# 12  [stablecoin, asset-backed-stablecoin, binance-...                NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 14  [defi, smart-contracts, three-arrows-capital-p...    720000000.00000
#
#       circulating_supply          total_supply  infinite_supply  platform  \
# 0         19346125.00000        19346125.00000            False       NaN
# 1        120217551.72073       120217551.72073            False       NaN
# 2      80765305448.28091     83091735571.84532            False       NaN
# 3        155866060.66001       155866060.66001            False       NaN
# 4      31802307983.64549     31802307983.64549            False       NaN
# 5      51750810378.00000     99988998998.00000            False       NaN
# 6      34774154472.53500     35677745726.91200            False       NaN
# 7     138937046383.70523    138937046383.70523            False       NaN
# 8       9219469069.28493     10000000000.00000            False       NaN
# 9        391770701.71471       539312704.88753            False       NaN
# 10      1176097785.67045      1302576662.97563            False       NaN
# 11        72703739.32100        84000000.00000            False       NaN
# 12      6715536683.91338      6715536683.91338            False       NaN
# 13 589536909347050.62500 589605139213047.62500            False       NaN
# 14       326192809.24692       422255529.24692            False       NaN
#
#     cmc_rank self_reported_circulating_supply self_reported_market_cap  \
# 0          1                             None                     None
# 1          2                             None                     None
# 2          3                             None                     None
# 3          4                             None                     None
# 4          5                             None                     None
# 5          6                             None                     None
# 6          7                             None                     None
# 7          8                             None                     None
# 8          9                             None                     None
# 9         10                             None                     None
# 10        11                             None                     None
# 11        12                             None                     None
# 12        13                             None                     None
# 13        14                             None                     None
# 14        15                             None                     None
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2023-04-14T17:38:00.000Z      30236.49072     22354450574.49229
# 1       None  2023-04-14T17:38:00.000Z       2073.90577     15642479029.68000
# 2       None  2023-04-14T17:38:00.000Z          1.00050     41394969779.38251
# 3       None  2023-04-14T17:38:00.000Z        326.93007       919391411.74978
# 4       None  2023-04-14T17:38:00.000Z          0.99960      6111024632.95115
# 5       None  2023-04-14T17:38:00.000Z          0.51869      1568176547.90414
# 6       None  2023-04-14T17:38:00.000Z          0.43138       780743407.62593
# 7       None  2023-04-14T17:38:00.000Z          0.08863       987483132.83592
# 8       None  2023-04-14T17:38:00.000Z          1.15064       583675363.10720
# 9       None  2023-04-14T17:38:00.000Z         24.14294       815435444.04777
# 10      None  2023-04-14T17:38:00.000Z          6.64303       297114917.19902
# 11      None  2023-04-14T17:38:00.000Z         94.81771       817892225.64705
# 12      None  2023-04-14T17:38:00.000Z          1.00037      4150944107.87883
# 13      None  2023-04-14T17:38:00.000Z          0.00001       288590651.26349
# 14      None  2023-04-14T17:38:00.000Z         18.69396       235060605.47188
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      26.65760                      0.34419
# 1                      20.68710                      1.03157
# 2                      30.54240                      0.01957
# 3                      32.97110                      0.77016
# 4                      33.99060                      0.02002
# 5                      62.46190                      0.78487
# 6                      65.95920                      0.67116
# 7                      13.93320                      2.61507
# 8                      99.67000                      0.82316
# 9                     -13.21620                      1.15133
# 10                     51.36340                      1.26965
# 11                     61.56310                      0.75574
# 12                      5.10700                      0.00453
# 13                     66.53930                      0.96749
# 14                    -13.96980                      0.84950
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -0.44240                      8.21892
# 1                        3.15810                     11.57702
# 2                       -0.03872                     -0.00369
# 3                        0.75249                      5.03155
# 4                       -0.02159                     -0.03205
# 5                        1.62206                      1.64219
# 6                        3.81634                     12.36760
# 7                        0.96157                      7.38586
# 8                        1.35425                      3.64607
# 9                       -2.02637                     17.58776
# 10                       0.65040                      7.28699
# 11                       0.58433                      4.78389
# 12                      -0.03125                      0.05737
# 13                       0.19206                      2.16514
# 14                      -1.34822                      6.04308
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       24.08550                      40.50068
# 1                       27.11484                      40.52246
# 2                       -0.13421                      -0.04847
# 3                        7.57233                      14.65877
# 4                        0.02979                      -0.02070
# 5                       43.69424                      42.05770
# 6                       33.98617                      23.72791
# 7                       28.82197                      10.11810
# 8                        4.70026                      -0.09339
# 9                       26.88797                      20.85425
# 10                      12.94765                      11.68385
# 11                      24.25992                       5.66624
# 12                       0.03837                       0.09240
# 13                       7.76207                      -7.72599
# 14                      19.38832                       9.46129
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       44.88374    584958929034.96887
# 1                       35.22627    249319874697.07614
# 2                        0.03237     80805948536.29919
# 3                        7.22217     50957301894.83282
# 4                       -0.04222     31789585709.28697
# 5                       31.73023     26842780561.44172
# 6                       22.50411     15000769378.40436
# 7                        1.56258     12314023298.23727
# 8                       16.01763     10608278478.67834
# 9                        4.34478      9458496663.10080
# 10                       8.75432      7812851534.05704
# 11                       7.53291      6893602244.70033
# 12                       0.00122      6718014327.90800
# 13                       7.87585      6584798175.06292
# 14                       9.93321      6097835025.18411
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         46.31860                  634966305124.89001
# 1                         19.73910                  249319874697.07999
# 2                          6.39760                   83133549376.72000
# 3                          4.03480                   50957301894.83000
# 4                          2.51710                   31789585709.29000
# 5                          2.12540                   51869295119.01000
# 6                          1.18760                   19411963634.12000
# 7                          0.97500                   12314023298.24000
# 8                          0.84000                   11506387622.71000
# 9                          0.74880                   13020594437.56000
# 10                         0.61860                    8653054366.35000
# 11                         0.54580                    7964687840.86000
# 12                         0.53190                    6718014327.91000
# 13                         0.52140                    6585560264.58000
# 14                         0.48280                   13459650530.83000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 1           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 2           None  2023-04-14T17:38:00.000Z   1027.00000      Ethereum
# 3           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 4           None  2023-04-14T17:38:00.000Z   1027.00000      Ethereum
# 5           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 6           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 7           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 8           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 9           None  2023-04-14T17:38:00.000Z          NaN           NaN
# 10          None  2023-04-14T17:38:00.000Z          NaN           NaN
# 11          None  2023-04-14T17:38:00.000Z          NaN           NaN
# 12          None  2023-04-14T17:38:00.000Z   1839.00000           BNB
# 13          None  2023-04-14T17:38:00.000Z   1027.00000      Ethereum
# 14          None  2023-04-14T17:38:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             BNB           bnb                                    BUSD-BD1
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-04-14 17:40:57.273952
# 1  2023-04-14 17:40:57.273952
# 2  2023-04-14 17:40:57.273952
# 3  2023-04-14 17:40:57.273952
# 4  2023-04-14 17:40:57.273952
# 5  2023-04-14 17:40:57.273952
# 6  2023-04-14 17:40:57.273952
# 7  2023-04-14 17:40:57.273952
# 8  2023-04-14 17:40:57.273952
# 9  2023-04-14 17:40:57.273952
# 10 2023-04-14 17:40:57.273952
# 11 2023-04-14 17:40:57.273952
# 12 2023-04-14 17:40:57.273952
# 13 2023-04-14 17:40:57.273952
# 14 2023-04-14 17:40:57.273952

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.34419                      -0.44240
# Ethereum                         1.03157                       3.15810
# Tether                           0.01957                      -0.03872
# BNB                              0.77016                       0.75249
# USD Coin                         0.02002                      -0.02159
# XRP                              0.78487                       1.62206
# Cardano                          0.67116                       3.81634
# Dogecoin                         2.61507                       0.96157
# Polygon                          0.82316                       1.35425
# Solana                           1.15133                      -2.02637
# Polkadot                         1.26965                       0.65040
# Litecoin                         0.75574                       0.58433
# Binance USD                      0.00453                      -0.03125
# Shiba Inu                        0.96749                       0.19206
# Avalanche                        0.84950                      -1.34822
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          8.21892                      24.08550
# Ethereum                        11.57702                      27.11484
# Tether                          -0.00369                      -0.13421
# BNB                              5.03155                       7.57233
# USD Coin                        -0.03205                       0.02979
# XRP                              1.64219                      43.69424
# Cardano                         12.36760                      33.98617
# Dogecoin                         7.38586                      28.82197
# Polygon                          3.64607                       4.70026
# Solana                          17.58776                      26.88797
# Polkadot                         7.28699                      12.94765
# Litecoin                         4.78389                      24.25992
# Binance USD                      0.05737                       0.03837
# Shiba Inu                        2.16514                       7.76207
# Avalanche                        6.04308                      19.38832
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          40.50068                      44.88374
# Ethereum                         40.52246                      35.22627
# Tether                           -0.04847                       0.03237
# BNB                              14.65877                       7.22217
# USD Coin                         -0.02070                      -0.04222
# XRP                              42.05770                      31.73023
# Cardano                          23.72791                      22.50411
# Dogecoin                         10.11810                       1.56258
# Polygon                          -0.09339                      16.01763
# Solana                           20.85425                       4.34478
# Polkadot                         11.68385                       8.75432
# Litecoin                          5.66624                       7.53291
# Binance USD                       0.09240                       0.00122
# Shiba Inu                        -7.72599                       7.87585
# Avalanche                         9.46129                       9.93321

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     0.34419
#              quote.USD.percent_change_24h   -0.44240
#              quote.USD.percent_change_7d     8.21892
#              quote.USD.percent_change_30d   24.08550
#              quote.USD.percent_change_60d   40.50068
#              quote.USD.percent_change_90d   44.88374
# Ethereum     quote.USD.percent_change_1h     1.03157
#              quote.USD.percent_change_24h    3.15810
#              quote.USD.percent_change_7d    11.57702
#              quote.USD.percent_change_30d   27.11484
#              quote.USD.percent_change_60d   40.52246
#              quote.USD.percent_change_90d   35.22627
# Tether       quote.USD.percent_change_1h     0.01957
#              quote.USD.percent_change_24h   -0.03872
#              quote.USD.percent_change_7d    -0.00369
#              quote.USD.percent_change_30d   -0.13421
#              quote.USD.percent_change_60d   -0.04847
#              quote.USD.percent_change_90d    0.03237
# BNB          quote.USD.percent_change_1h     0.77016
#              quote.USD.percent_change_24h    0.75249
#              quote.USD.percent_change_7d     5.03155
#              quote.USD.percent_change_30d    7.57233
#              quote.USD.percent_change_60d   14.65877
#              quote.USD.percent_change_90d    7.22217
# USD Coin     quote.USD.percent_change_1h     0.02002
#              quote.USD.percent_change_24h   -0.02159
#              quote.USD.percent_change_7d    -0.03205
#              quote.USD.percent_change_30d    0.02979
#              quote.USD.percent_change_60d   -0.02070
#              quote.USD.percent_change_90d   -0.04222
# XRP          quote.USD.percent_change_1h     0.78487
#              quote.USD.percent_change_24h    1.62206
#              quote.USD.percent_change_7d     1.64219
#              quote.USD.percent_change_30d   43.69424
#              quote.USD.percent_change_60d   42.05770
#              quote.USD.percent_change_90d   31.73023
# Cardano      quote.USD.percent_change_1h     0.67116
#              quote.USD.percent_change_24h    3.81634
#              quote.USD.percent_change_7d    12.36760
#              quote.USD.percent_change_30d   33.98617
#              quote.USD.percent_change_60d   23.72791
#              quote.USD.percent_change_90d   22.50411
# Dogecoin     quote.USD.percent_change_1h     2.61507
#              quote.USD.percent_change_24h    0.96157
#              quote.USD.percent_change_7d     7.38586
#              quote.USD.percent_change_30d   28.82197
#              quote.USD.percent_change_60d   10.11810
#              quote.USD.percent_change_90d    1.56258
# Polygon      quote.USD.percent_change_1h     0.82316
#              quote.USD.percent_change_24h    1.35425
#              quote.USD.percent_change_7d     3.64607
#              quote.USD.percent_change_30d    4.70026
#              quote.USD.percent_change_60d   -0.09339
#              quote.USD.percent_change_90d   16.01763
# Solana       quote.USD.percent_change_1h     1.15133
#              quote.USD.percent_change_24h   -2.02637
#              quote.USD.percent_change_7d    17.58776
#              quote.USD.percent_change_30d   26.88797
#              quote.USD.percent_change_60d   20.85425
#              quote.USD.percent_change_90d    4.34478
# Polkadot     quote.USD.percent_change_1h     1.26965
#              quote.USD.percent_change_24h    0.65040
#              quote.USD.percent_change_7d     7.28699
#              quote.USD.percent_change_30d   12.94765
#              quote.USD.percent_change_60d   11.68385
#              quote.USD.percent_change_90d    8.75432
# Litecoin     quote.USD.percent_change_1h     0.75574
#              quote.USD.percent_change_24h    0.58433
#              quote.USD.percent_change_7d     4.78389
#              quote.USD.percent_change_30d   24.25992
#              quote.USD.percent_change_60d    5.66624
#              quote.USD.percent_change_90d    7.53291
# Binance USD  quote.USD.percent_change_1h     0.00453
#              quote.USD.percent_change_24h   -0.03125
#              quote.USD.percent_change_7d     0.05737
#              quote.USD.percent_change_30d    0.03837
#              quote.USD.percent_change_60d    0.09240
#              quote.USD.percent_change_90d    0.00122
# Shiba Inu    quote.USD.percent_change_1h     0.96749
#              quote.USD.percent_change_24h    0.19206
#              quote.USD.percent_change_7d     2.16514
#              quote.USD.percent_change_30d    7.76207
#              quote.USD.percent_change_60d   -7.72599
#              quote.USD.percent_change_90d    7.87585
# Avalanche    quote.USD.percent_change_1h     0.84950
#              quote.USD.percent_change_24h   -1.34822
#              quote.USD.percent_change_7d     6.04308
#              quote.USD.percent_change_30d   19.38832
#              quote.USD.percent_change_60d    9.46129
#              quote.USD.percent_change_90d    9.93321
# dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                            values
# name
# Bitcoin     quote.USD.percent_change_1h   0.34419
#             quote.USD.percent_change_24h -0.44240
#             quote.USD.percent_change_7d   8.21892
#             quote.USD.percent_change_30d 24.08550
#             quote.USD.percent_change_60d 40.50068
#             quote.USD.percent_change_90d 44.88374
# Ethereum    quote.USD.percent_change_1h   1.03157
#             quote.USD.percent_change_24h  3.15810
#             quote.USD.percent_change_7d  11.57702
#             quote.USD.percent_change_30d 27.11484
#             quote.USD.percent_change_60d 40.52246
#             quote.USD.percent_change_90d 35.22627
# Tether      quote.USD.percent_change_1h   0.01957
#             quote.USD.percent_change_24h -0.03872
#             quote.USD.percent_change_7d  -0.00369
#             quote.USD.percent_change_30d -0.13421
#             quote.USD.percent_change_60d -0.04847
#             quote.USD.percent_change_90d  0.03237
# BNB         quote.USD.percent_change_1h   0.77016
#             quote.USD.percent_change_24h  0.75249
#             quote.USD.percent_change_7d   5.03155
#             quote.USD.percent_change_30d  7.57233
#             quote.USD.percent_change_60d 14.65877
#             quote.USD.percent_change_90d  7.22217
# USD Coin    quote.USD.percent_change_1h   0.02002
#             quote.USD.percent_change_24h -0.02159
#             quote.USD.percent_change_7d  -0.03205
#             quote.USD.percent_change_30d  0.02979
#             quote.USD.percent_change_60d -0.02070
#             quote.USD.percent_change_90d -0.04222
# XRP         quote.USD.percent_change_1h   0.78487
#             quote.USD.percent_change_24h  1.62206
#             quote.USD.percent_change_7d   1.64219
#             quote.USD.percent_change_30d 43.69424
#             quote.USD.percent_change_60d 42.05770
#             quote.USD.percent_change_90d 31.73023
# Cardano     quote.USD.percent_change_1h   0.67116
#             quote.USD.percent_change_24h  3.81634
#             quote.USD.percent_change_7d  12.36760
#             quote.USD.percent_change_30d 33.98617
#             quote.USD.percent_change_60d 23.72791
#             quote.USD.percent_change_90d 22.50411
# Dogecoin    quote.USD.percent_change_1h   2.61507
#             quote.USD.percent_change_24h  0.96157
#             quote.USD.percent_change_7d   7.38586
#             quote.USD.percent_change_30d 28.82197
#             quote.USD.percent_change_60d 10.11810
#             quote.USD.percent_change_90d  1.56258
# Polygon     quote.USD.percent_change_1h   0.82316
#             quote.USD.percent_change_24h  1.35425
#             quote.USD.percent_change_7d   3.64607
#             quote.USD.percent_change_30d  4.70026
#             quote.USD.percent_change_60d -0.09339
#             quote.USD.percent_change_90d 16.01763
# Solana      quote.USD.percent_change_1h   1.15133
#             quote.USD.percent_change_24h -2.02637
#             quote.USD.percent_change_7d  17.58776
#             quote.USD.percent_change_30d 26.88797
#             quote.USD.percent_change_60d 20.85425
#             quote.USD.percent_change_90d  4.34478
# Polkadot    quote.USD.percent_change_1h   1.26965
#             quote.USD.percent_change_24h  0.65040
#             quote.USD.percent_change_7d   7.28699
#             quote.USD.percent_change_30d 12.94765
#             quote.USD.percent_change_60d 11.68385
#             quote.USD.percent_change_90d  8.75432
# Litecoin    quote.USD.percent_change_1h   0.75574
#             quote.USD.percent_change_24h  0.58433
#             quote.USD.percent_change_7d   4.78389
#             quote.USD.percent_change_30d 24.25992
#             quote.USD.percent_change_60d  5.66624
#             quote.USD.percent_change_90d  7.53291
# Binance USD quote.USD.percent_change_1h   0.00453
#             quote.USD.percent_change_24h -0.03125
#             quote.USD.percent_change_7d   0.05737
#             quote.USD.percent_change_30d  0.03837
#             quote.USD.percent_change_60d  0.09240
#             quote.USD.percent_change_90d  0.00122
# Shiba Inu   quote.USD.percent_change_1h   0.96749
#             quote.USD.percent_change_24h  0.19206
#             quote.USD.percent_change_7d   2.16514
#             quote.USD.percent_change_30d  7.76207
#             quote.USD.percent_change_60d -7.72599
#             quote.USD.percent_change_90d  7.87585
# Avalanche   quote.USD.percent_change_1h   0.84950
#             quote.USD.percent_change_24h -1.34822
#             quote.USD.percent_change_7d   6.04308
#             quote.USD.percent_change_30d 19.38832
#             quote.USD.percent_change_60d  9.46129
#             quote.USD.percent_change_90d  9.93321

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6
# Out:
#            name                       level_1   values
# 0       Bitcoin   quote.USD.percent_change_1h  0.34419
# 1       Bitcoin  quote.USD.percent_change_24h -0.44240
# 2       Bitcoin   quote.USD.percent_change_7d  8.21892
# 3       Bitcoin  quote.USD.percent_change_30d 24.08550
# 4       Bitcoin  quote.USD.percent_change_60d 40.50068
# 5       Bitcoin  quote.USD.percent_change_90d 44.88374
# 6      Ethereum   quote.USD.percent_change_1h  1.03157
# 7      Ethereum  quote.USD.percent_change_24h  3.15810
# 8      Ethereum   quote.USD.percent_change_7d 11.57702
# 9      Ethereum  quote.USD.percent_change_30d 27.11484
# 10     Ethereum  quote.USD.percent_change_60d 40.52246
# 11     Ethereum  quote.USD.percent_change_90d 35.22627
# 12       Tether   quote.USD.percent_change_1h  0.01957
# 13       Tether  quote.USD.percent_change_24h -0.03872
# 14       Tether   quote.USD.percent_change_7d -0.00369
# 15       Tether  quote.USD.percent_change_30d -0.13421
# 16       Tether  quote.USD.percent_change_60d -0.04847
# 17       Tether  quote.USD.percent_change_90d  0.03237
# 18          BNB   quote.USD.percent_change_1h  0.77016
# 19          BNB  quote.USD.percent_change_24h  0.75249
# 20          BNB   quote.USD.percent_change_7d  5.03155
# 21          BNB  quote.USD.percent_change_30d  7.57233
# 22          BNB  quote.USD.percent_change_60d 14.65877
# 23          BNB  quote.USD.percent_change_90d  7.22217
# 24     USD Coin   quote.USD.percent_change_1h  0.02002
# 25     USD Coin  quote.USD.percent_change_24h -0.02159
# 26     USD Coin   quote.USD.percent_change_7d -0.03205
# 27     USD Coin  quote.USD.percent_change_30d  0.02979
# 28     USD Coin  quote.USD.percent_change_60d -0.02070
# 29     USD Coin  quote.USD.percent_change_90d -0.04222
# 30          XRP   quote.USD.percent_change_1h  0.78487
# 31          XRP  quote.USD.percent_change_24h  1.62206
# 32          XRP   quote.USD.percent_change_7d  1.64219
# 33          XRP  quote.USD.percent_change_30d 43.69424
# 34          XRP  quote.USD.percent_change_60d 42.05770
# 35          XRP  quote.USD.percent_change_90d 31.73023
# 36      Cardano   quote.USD.percent_change_1h  0.67116
# 37      Cardano  quote.USD.percent_change_24h  3.81634
# 38      Cardano   quote.USD.percent_change_7d 12.36760
# 39      Cardano  quote.USD.percent_change_30d 33.98617
# 40      Cardano  quote.USD.percent_change_60d 23.72791
# 41      Cardano  quote.USD.percent_change_90d 22.50411
# 42     Dogecoin   quote.USD.percent_change_1h  2.61507
# 43     Dogecoin  quote.USD.percent_change_24h  0.96157
# 44     Dogecoin   quote.USD.percent_change_7d  7.38586
# 45     Dogecoin  quote.USD.percent_change_30d 28.82197
# 46     Dogecoin  quote.USD.percent_change_60d 10.11810
# 47     Dogecoin  quote.USD.percent_change_90d  1.56258
# 48      Polygon   quote.USD.percent_change_1h  0.82316
# 49      Polygon  quote.USD.percent_change_24h  1.35425
# 50      Polygon   quote.USD.percent_change_7d  3.64607
# 51      Polygon  quote.USD.percent_change_30d  4.70026
# 52      Polygon  quote.USD.percent_change_60d -0.09339
# 53      Polygon  quote.USD.percent_change_90d 16.01763
# 54       Solana   quote.USD.percent_change_1h  1.15133
# 55       Solana  quote.USD.percent_change_24h -2.02637
# 56       Solana   quote.USD.percent_change_7d 17.58776
# 57       Solana  quote.USD.percent_change_30d 26.88797
# 58       Solana  quote.USD.percent_change_60d 20.85425
# 59       Solana  quote.USD.percent_change_90d  4.34478
# 60     Polkadot   quote.USD.percent_change_1h  1.26965
# 61     Polkadot  quote.USD.percent_change_24h  0.65040
# 62     Polkadot   quote.USD.percent_change_7d  7.28699
# 63     Polkadot  quote.USD.percent_change_30d 12.94765
# 64     Polkadot  quote.USD.percent_change_60d 11.68385
# 65     Polkadot  quote.USD.percent_change_90d  8.75432
# 66     Litecoin   quote.USD.percent_change_1h  0.75574
# 67     Litecoin  quote.USD.percent_change_24h  0.58433
# 68     Litecoin   quote.USD.percent_change_7d  4.78389
# 69     Litecoin  quote.USD.percent_change_30d 24.25992
# 70     Litecoin  quote.USD.percent_change_60d  5.66624
# 71     Litecoin  quote.USD.percent_change_90d  7.53291
# 72  Binance USD   quote.USD.percent_change_1h  0.00453
# 73  Binance USD  quote.USD.percent_change_24h -0.03125
# 74  Binance USD   quote.USD.percent_change_7d  0.05737
# 75  Binance USD  quote.USD.percent_change_30d  0.03837
# 76  Binance USD  quote.USD.percent_change_60d  0.09240
# 77  Binance USD  quote.USD.percent_change_90d  0.00122
# 78    Shiba Inu   quote.USD.percent_change_1h  0.96749
# 79    Shiba Inu  quote.USD.percent_change_24h  0.19206
# 80    Shiba Inu   quote.USD.percent_change_7d  2.16514
# 81    Shiba Inu  quote.USD.percent_change_30d  7.76207
# 82    Shiba Inu  quote.USD.percent_change_60d -7.72599
# 83    Shiba Inu  quote.USD.percent_change_90d  7.87585
# 84    Avalanche   quote.USD.percent_change_1h  0.84950
# 85    Avalanche  quote.USD.percent_change_24h -1.34822
# 86    Avalanche   quote.USD.percent_change_7d  6.04308
# 87    Avalanche  quote.USD.percent_change_30d 19.38832
# 88    Avalanche  quote.USD.percent_change_60d  9.46129
# 89    Avalanche  quote.USD.percent_change_90d  9.93321

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change   values
# 0       Bitcoin   quote.USD.percent_change_1h  0.34419
# 1       Bitcoin  quote.USD.percent_change_24h -0.44240
# 2       Bitcoin   quote.USD.percent_change_7d  8.21892
# 3       Bitcoin  quote.USD.percent_change_30d 24.08550
# 4       Bitcoin  quote.USD.percent_change_60d 40.50068
# 5       Bitcoin  quote.USD.percent_change_90d 44.88374
# 6      Ethereum   quote.USD.percent_change_1h  1.03157
# 7      Ethereum  quote.USD.percent_change_24h  3.15810
# 8      Ethereum   quote.USD.percent_change_7d 11.57702
# 9      Ethereum  quote.USD.percent_change_30d 27.11484
# 10     Ethereum  quote.USD.percent_change_60d 40.52246
# 11     Ethereum  quote.USD.percent_change_90d 35.22627
# 12       Tether   quote.USD.percent_change_1h  0.01957
# 13       Tether  quote.USD.percent_change_24h -0.03872
# 14       Tether   quote.USD.percent_change_7d -0.00369
# 15       Tether  quote.USD.percent_change_30d -0.13421
# 16       Tether  quote.USD.percent_change_60d -0.04847
# 17       Tether  quote.USD.percent_change_90d  0.03237
# 18          BNB   quote.USD.percent_change_1h  0.77016
# 19          BNB  quote.USD.percent_change_24h  0.75249
# 20          BNB   quote.USD.percent_change_7d  5.03155
# 21          BNB  quote.USD.percent_change_30d  7.57233
# 22          BNB  quote.USD.percent_change_60d 14.65877
# 23          BNB  quote.USD.percent_change_90d  7.22217
# 24     USD Coin   quote.USD.percent_change_1h  0.02002
# 25     USD Coin  quote.USD.percent_change_24h -0.02159
# 26     USD Coin   quote.USD.percent_change_7d -0.03205
# 27     USD Coin  quote.USD.percent_change_30d  0.02979
# 28     USD Coin  quote.USD.percent_change_60d -0.02070
# 29     USD Coin  quote.USD.percent_change_90d -0.04222
# 30          XRP   quote.USD.percent_change_1h  0.78487
# 31          XRP  quote.USD.percent_change_24h  1.62206
# 32          XRP   quote.USD.percent_change_7d  1.64219
# 33          XRP  quote.USD.percent_change_30d 43.69424
# 34          XRP  quote.USD.percent_change_60d 42.05770
# 35          XRP  quote.USD.percent_change_90d 31.73023
# 36      Cardano   quote.USD.percent_change_1h  0.67116
# 37      Cardano  quote.USD.percent_change_24h  3.81634
# 38      Cardano   quote.USD.percent_change_7d 12.36760
# 39      Cardano  quote.USD.percent_change_30d 33.98617
# 40      Cardano  quote.USD.percent_change_60d 23.72791
# 41      Cardano  quote.USD.percent_change_90d 22.50411
# 42     Dogecoin   quote.USD.percent_change_1h  2.61507
# 43     Dogecoin  quote.USD.percent_change_24h  0.96157
# 44     Dogecoin   quote.USD.percent_change_7d  7.38586
# 45     Dogecoin  quote.USD.percent_change_30d 28.82197
# 46     Dogecoin  quote.USD.percent_change_60d 10.11810
# 47     Dogecoin  quote.USD.percent_change_90d  1.56258
# 48      Polygon   quote.USD.percent_change_1h  0.82316
# 49      Polygon  quote.USD.percent_change_24h  1.35425
# 50      Polygon   quote.USD.percent_change_7d  3.64607
# 51      Polygon  quote.USD.percent_change_30d  4.70026
# 52      Polygon  quote.USD.percent_change_60d -0.09339
# 53      Polygon  quote.USD.percent_change_90d 16.01763
# 54       Solana   quote.USD.percent_change_1h  1.15133
# 55       Solana  quote.USD.percent_change_24h -2.02637
# 56       Solana   quote.USD.percent_change_7d 17.58776
# 57       Solana  quote.USD.percent_change_30d 26.88797
# 58       Solana  quote.USD.percent_change_60d 20.85425
# 59       Solana  quote.USD.percent_change_90d  4.34478
# 60     Polkadot   quote.USD.percent_change_1h  1.26965
# 61     Polkadot  quote.USD.percent_change_24h  0.65040
# 62     Polkadot   quote.USD.percent_change_7d  7.28699
# 63     Polkadot  quote.USD.percent_change_30d 12.94765
# 64     Polkadot  quote.USD.percent_change_60d 11.68385
# 65     Polkadot  quote.USD.percent_change_90d  8.75432
# 66     Litecoin   quote.USD.percent_change_1h  0.75574
# 67     Litecoin  quote.USD.percent_change_24h  0.58433
# 68     Litecoin   quote.USD.percent_change_7d  4.78389
# 69     Litecoin  quote.USD.percent_change_30d 24.25992
# 70     Litecoin  quote.USD.percent_change_60d  5.66624
# 71     Litecoin  quote.USD.percent_change_90d  7.53291
# 72  Binance USD   quote.USD.percent_change_1h  0.00453
# 73  Binance USD  quote.USD.percent_change_24h -0.03125
# 74  Binance USD   quote.USD.percent_change_7d  0.05737
# 75  Binance USD  quote.USD.percent_change_30d  0.03837
# 76  Binance USD  quote.USD.percent_change_60d  0.09240
# 77  Binance USD  quote.USD.percent_change_90d  0.00122
# 78    Shiba Inu   quote.USD.percent_change_1h  0.96749
# 79    Shiba Inu  quote.USD.percent_change_24h  0.19206
# 80    Shiba Inu   quote.USD.percent_change_7d  2.16514
# 81    Shiba Inu  quote.USD.percent_change_30d  7.76207
# 82    Shiba Inu  quote.USD.percent_change_60d -7.72599
# 83    Shiba Inu  quote.USD.percent_change_90d  7.87585
# 84    Avalanche   quote.USD.percent_change_1h  0.84950
# 85    Avalanche  quote.USD.percent_change_24h -1.34822
# 86    Avalanche   quote.USD.percent_change_7d  6.04308
# 87    Avalanche  quote.USD.percent_change_30d 19.38832
# 88    Avalanche  quote.USD.percent_change_60d  9.46129
# 89    Avalanche  quote.USD.percent_change_90d  9.93321

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
#            name               percent_change   values
# 0       Bitcoin  quote.USD.percent_change_1h  0.34419
# 1       Bitcoin                          24h -0.44240
# 2       Bitcoin                           7d  8.21892
# 3       Bitcoin                          30d 24.08550
# 4       Bitcoin                          60d 40.50068
# 5       Bitcoin                          90d 44.88374
# 6      Ethereum  quote.USD.percent_change_1h  1.03157
# 7      Ethereum                          24h  3.15810
# 8      Ethereum                           7d 11.57702
# 9      Ethereum                          30d 27.11484
# 10     Ethereum                          60d 40.52246
# 11     Ethereum                          90d 35.22627
# 12       Tether  quote.USD.percent_change_1h  0.01957
# 13       Tether                          24h -0.03872
# 14       Tether                           7d -0.00369
# 15       Tether                          30d -0.13421
# 16       Tether                          60d -0.04847
# 17       Tether                          90d  0.03237
# 18          BNB  quote.USD.percent_change_1h  0.77016
# 19          BNB                          24h  0.75249
# 20          BNB                           7d  5.03155
# 21          BNB                          30d  7.57233
# 22          BNB                          60d 14.65877
# 23          BNB                          90d  7.22217
# 24     USD Coin  quote.USD.percent_change_1h  0.02002
# 25     USD Coin                          24h -0.02159
# 26     USD Coin                           7d -0.03205
# 27     USD Coin                          30d  0.02979
# 28     USD Coin                          60d -0.02070
# 29     USD Coin                          90d -0.04222
# 30          XRP  quote.USD.percent_change_1h  0.78487
# 31          XRP                          24h  1.62206
# 32          XRP                           7d  1.64219
# 33          XRP                          30d 43.69424
# 34          XRP                          60d 42.05770
# 35          XRP                          90d 31.73023
# 36      Cardano  quote.USD.percent_change_1h  0.67116
# 37      Cardano                          24h  3.81634
# 38      Cardano                           7d 12.36760
# 39      Cardano                          30d 33.98617
# 40      Cardano                          60d 23.72791
# 41      Cardano                          90d 22.50411
# 42     Dogecoin  quote.USD.percent_change_1h  2.61507
# 43     Dogecoin                          24h  0.96157
# 44     Dogecoin                           7d  7.38586
# 45     Dogecoin                          30d 28.82197
# 46     Dogecoin                          60d 10.11810
# 47     Dogecoin                          90d  1.56258
# 48      Polygon  quote.USD.percent_change_1h  0.82316
# 49      Polygon                          24h  1.35425
# 50      Polygon                           7d  3.64607
# 51      Polygon                          30d  4.70026
# 52      Polygon                          60d -0.09339
# 53      Polygon                          90d 16.01763
# 54       Solana  quote.USD.percent_change_1h  1.15133
# 55       Solana                          24h -2.02637
# 56       Solana                           7d 17.58776
# 57       Solana                          30d 26.88797
# 58       Solana                          60d 20.85425
# 59       Solana                          90d  4.34478
# 60     Polkadot  quote.USD.percent_change_1h  1.26965
# 61     Polkadot                          24h  0.65040
# 62     Polkadot                           7d  7.28699
# 63     Polkadot                          30d 12.94765
# 64     Polkadot                          60d 11.68385
# 65     Polkadot                          90d  8.75432
# 66     Litecoin  quote.USD.percent_change_1h  0.75574
# 67     Litecoin                          24h  0.58433
# 68     Litecoin                           7d  4.78389
# 69     Litecoin                          30d 24.25992
# 70     Litecoin                          60d  5.66624
# 71     Litecoin                          90d  7.53291
# 72  Binance USD  quote.USD.percent_change_1h  0.00453
# 73  Binance USD                          24h -0.03125
# 74  Binance USD                           7d  0.05737
# 75  Binance USD                          30d  0.03837
# 76  Binance USD                          60d  0.09240
# 77  Binance USD                          90d  0.00122
# 78    Shiba Inu  quote.USD.percent_change_1h  0.96749
# 79    Shiba Inu                          24h  0.19206
# 80    Shiba Inu                           7d  2.16514
# 81    Shiba Inu                          30d  7.76207
# 82    Shiba Inu                          60d -7.72599
# 83    Shiba Inu                          90d  7.87585
# 84    Avalanche  quote.USD.percent_change_1h  0.84950
# 85    Avalanche                          24h -1.34822
# 86    Avalanche                           7d  6.04308
# 87    Avalanche                          30d 19.38832
# 88    Avalanche                          60d  9.46129
# 89    Avalanche                          90d  9.93321

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      30236.49072 2023-04-14 17:40:57.273952

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <AxesSubplot:xlabel='percent_change', ylabel='values'>
